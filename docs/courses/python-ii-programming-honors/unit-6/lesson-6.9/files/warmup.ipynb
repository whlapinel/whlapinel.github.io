# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 100)
y1 = x *2
y2 = x*3
plt.plot(x, y1, label="y=2x")
plt.plot(x, y2, label="y=3x")
plt.title("y=2x and y=3x")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
